# %% [markdown]
# # Transformer encoder를 이용하여 DSA 분류

# %% [markdown]
# ## 1. 데이터 분석 및 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\tbxjq\\Desktop\\가천대학교\\3학년 2학기\\딥러닝 응용\\Deep_learning_class\\data\\DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9120 entries, 0 to 9119
# Columns: 272 entries, T_xacc_mean to people
# dtypes: float64(270), object(2)
# memory usage: 18.9+ MB

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# T_xacc_mean     0
# T_xacc_max      0
# T_xacc_min      0
# T_xacc_var      0
# T_xacc_std      0
#                ..
# LL_zmag_var     0
# LL_zmag_std     0
# LL_zmag_skew    0
# activity        0
# people          0
# Length: 272, dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **시계열 데이터로 변환**

# %%
# 사람별, 활동별로 그룹화하여 데이터 개수를 세는 코드
activity_count = df.groupby(['people', 'activity']).size().reset_index(name='count')

# 결과 확인
print(activity_count)

# 사람이 하나의 활동을 한 데이터가 각각 60개가 저장되어있음 -> 시퀀스 길이 조정하여 모델 구성
# Out:
#     people                 activity  count
# 0       p1          ascendingStairs     60
# 1       p1               basketBall     60
# 2       p1             crossTrainer     60
# 3       p1        cyclingHorizontal     60
# 4       p1          cyclingVertical     60
# ..     ...                      ...    ...
# 147     p8  standingInElevatorStill     60
# 148     p8                  stepper     60
# 149     p8               walkingLot     60
# 150     p8     walkingTreadmillFlat     60
# 151     p8  walkingTreadmillIncline     60
#
# [152 rows x 3 columns]

# %%
df=df.drop(['people'],axis=1)
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 9115  4.033226e-02     0.200829     -0.040701      0.297666     0.708480
# 9116  2.212497e-02     0.148745     -0.266377      0.224716     0.554670
# 9117  9.656444e-02     0.310748     -0.009505     -0.237786     0.088854
# 9118  2.448990e-02     0.156493      0.050624      0.533023     0.677800
# 9119  5.251176e-02     0.229154     -0.342228      0.491919     0.707920
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729     sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471     sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579     sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690     sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429     sitting
# ...           ...           ...          ...           ...         ...
# 9115    -0.117430  4.135451e-02     0.203358     -0.310022  basketBall
# 9116    -0.250950  3.355704e-02     0.183186     -0.736410  basketBall
# 9117    -0.477260  2.026107e-02     0.142341      0.668438  basketBall
# 9118     0.055941  1.356379e-02     0.116464     -1.482489  basketBall
# 9119     0.251280  9.358254e-03     0.096738     -0.223302  basketBall
#
# [9120 rows x 271 columns]

# %%
df['activity'].value_counts()
# Out:
# activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df['activity'] = label_encoder.fit_transform(df['activity'])

# %%
df['activity'].value_counts()
# Out:
# activity
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: count, dtype: int64

# %%
input = df.drop(['activity'],axis=1)
target = df['activity']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(input,target,test_size=0.2)

x_test,y_test
# Out:
# (      T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
#  8101     9.080282     12.4760      5.2694    1.587705    1.260042
#  219      9.200450      9.2940      9.0778    0.000989    0.031446
#  3058     9.354737      9.5496      9.2648    0.002721    0.052163
#  6564     9.262765     12.9170      4.5175    3.965777    1.991426
#  2333     9.268122     14.1260      6.6404    2.794140    1.671568
#  ...           ...         ...         ...         ...         ...
#  6822     9.457174     11.0320      8.0779    0.335629    0.579335
#  3034     9.510186      9.9525      9.0432    0.057518    0.239828
#  2590     9.097475     12.5400      6.7374    1.078955    1.038727
#  1894     2.621082      2.6590      2.5624    0.000329    0.018125
#  4577     8.761047     12.8140      6.5564    2.222491    1.490802
#
#        T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
#  8101    -0.474270     0.003343    2.894400    -3.20440    0.726651  ...
#  219     -0.611262    -1.558013   -1.514300    -1.61810    0.000421  ...
#  3058     1.162385    -0.325756   -0.069604    -0.51478    0.007543  ...
#  6564    -0.443402    -0.343446    2.240400    -2.50280    1.045463  ...
#  2333     0.894335    -1.326259    1.779100    -4.63310    2.033738  ...
#  ...           ...          ...         ...         ...         ...  ...
#  6822     0.059559     0.206235    1.293200    -0.92895    0.282809  ...
#  3034     0.550564    -0.169316    0.110780    -0.29718    0.003780  ...
#  2590     0.873313    -2.238785   -0.901230    -4.83020    0.836433  ...
#  1894    -0.183811    -9.385749   -9.350600    -9.44070    0.000274  ...
#  4577     0.884177    -0.372337    1.045600    -1.88550    0.339653  ...
#
#        LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
#  8101      0.80374  4.192720e-03     0.064751      0.124266     -0.017457
#  219       0.43630  4.305080e-07     0.000656      0.466351      0.566769
#  3058      0.28989  2.925067e-05     0.005408      0.149155     -0.318987
#  6564      0.18518  1.358750e-02     0.116565     -0.178251      0.054335
#  2333      0.20455  2.289451e-02     0.151309      0.456757     -0.296058
#  ...           ...           ...          ...           ...           ...
#  6822      0.30315  4.449751e-03     0.066706     -0.474537      0.438753
#  3034     -0.24739  6.227278e-03     0.078913     -1.989572     -0.112623
#  2590     -0.48301  3.844852e-03     0.062007      0.264592      0.637249
#  1894     -0.54594  5.876658e-05     0.007666      0.212282     -0.412666
#  4577      0.16979  3.362821e-02     0.183380     -0.457998      0.320576
#
#        LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
#  8101     0.050691    -0.078989  1.439368e-03     0.037939     -0.108076
#  219      0.568280     0.564480  5.333078e-07     0.000730     -0.313697
#  3058    -0.310840    -0.324910  8.853665e-06     0.002976      0.061043
#  6564     0.116740    -0.029118  1.326338e-03     0.036419     -0.294440
#  2333    -0.198390    -0.363360  1.113467e-03     0.033369      0.448555
#  ...           ...          ...           ...          ...           ...
#  6822     0.471850     0.388180  3.464317e-04     0.018613     -0.293103
#  3034    -0.056087    -0.131480  3.423734e-04     0.018503      1.083012
#  2590     0.708220     0.552470  1.780879e-03     0.042200      0.054208
#  1894    -0.390280    -0.436460  6.508504e-05     0.008068     -0.404630
#  4577     0.416360     0.206930  2.896049e-03     0.053815      0.001915
#
#  [1824 rows x 270 columns],
#  8101    10
#  219     12
#  3058    14
#  6564     2
#  2333     0
#          ..
#  6822     3
#  3034    14
#  2590     5
#  1894     8
#  4577    17
#  Name: activity, Length: 1824, dtype: int32)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7296, 270), (1824, 270), (7296,), (1824,))

# %%
from sklearn.preprocessing import StandardScaler
# StandardScaler 적용
ss = StandardScaler()
x_train= ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
from collections import Counter

# timeseries
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # 시퀀스의 끝 인덱스 계산
        end_ix = i + n_steps
        if end_ix > len(sequences):  # 데이터 범위를 넘으면 종료
            break
        
        # 입력과 출력 데이터를 추출
        seq_x = sequences[i:end_ix, :-1]  # 입력 데이터
        seq_y_values = sequences[i:end_ix, -1]  # 해당 구간의 레이블들

        # 가장 빈번한 레이블을 선택
        most_common_label = Counter(seq_y_values).most_common(1)[0][0]

        X.append(seq_x)  # 입력 데이터 추가
        y.append(most_common_label)  # 가장 많이 나온 레이블 추가

    return np.array(X), np.array(y)  # Numpy 배열로 변환하여 반환

# %%
# 시계열 데이터로 만들기 위해서 데이터 전처리 과정에서 train test x/y로 나눴는데 
# y(target)을 x(input) 뒤에 붙여줘야 이 함수가 작동함. 시계열에 맞는 새로운 label이 필요하기 때문!

y_train_arr = np.array(y_train)
train_set = np.c_[x_train,y_train]

y_test_arr = np.array(y_test)
test_set = np.c_[x_test,y_test]

# %%
n_step=20

x_train,y_train = split_sequences(train_set,n_step)
x_test,y_test = split_sequences(test_set,n_step)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7277, 20, 270), (1805, 20, 270), (7277,), (1805,))

# %%
 #정수형 레이블을 벡터로 바꿔주기 원-핫 인코딩

from keras.utils import to_categorical
y_train= to_categorical(y_train)
y_test = to_categorical(y_test)

y_train.shape, y_test.shape
# Out:
# ((7277, 19), (1805, 19))

# %%
# Produce variables for CNN/LSTM/Transformer input/output shape
n_timesteps, n_features, n_outputs = x_train.shape[1], x_train.shape[2], y_train.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 20 270 19

# %% [markdown]
# ## 2. 트렌스포머 모델 정의 및 학습

# %% [markdown]
# 트랜스포머 인코더 모델 구조
#
# 입력 임베딩: 입력 데이터를 적절한 차원으로 임베딩.
#
# 포지셔널 인코딩: 입력 데이터가 순차적인 관계를 학습할 수 있도록 순서 정보를 추가.
#
# 멀티헤드 어텐션: 입력 데이터 간의 상관관계를 학습.
#
# 피드 포워드 네트워크: 학습된 정보를 처리하는 층.
#
# 최종 분류 층: 입력에 대한 예측을 수행하는 층.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout,MultiHeadAttention,LayerNormalization
from tensorflow.keras.models import Model
from tensorflow import keras
from tensorflow.keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
# 하이퍼파라미터 설정
input_shape = (n_timesteps, n_features)  # 시퀀스 길이, 피처 수
n_classes = n_outputs  # 클래스 수
dropout = 0.3 # 드롭아웃 비율


model = build_model(
    input_shape=input_shape,
    head_size=64,
    num_heads=2,
    ff_dim=64,
    num_transformer_blocks=1,
    mlp_units=[64, 32],
    dropout=dropout,
    mlp_dropout=dropout
)

# 모델 요약

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 요약
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 20, 270)]    0           []
#
#  multi_head_attention (MultiHea  (None, 20, 270)     138894      ['input_2[0][0]',
#  dAttention)                                                      'input_2[0][0]']
#
#  dropout (Dropout)              (None, 20, 270)      0           ['multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 20, 270)     540         ['dropout[0][0]']
#  alization)
#
#  tf.__operators__.add (TFOpLamb  (None, 20, 270)     0           ['layer_normalization[0][0]',
#  da)                                                              'input_2[0][0]']
#
#  conv1d (Conv1D)                (None, 20, 64)       17344       ['tf.__operators__.add[0][0]']
#
#  dropout_1 (Dropout)            (None, 20, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 20, 270)      17550       ['dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 20, 270)     540         ['conv1d_1[0][0]']
#  rmalization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  global_average_pooling1d (Glob  (None, 270)         0           ['tf.__operators__.add_1[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 64)           17344       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_2 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 32)           2080        ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 32)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 19)           627         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 194,919
# Trainable params: 194,919
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 학습
history = model.fit(x_train, y_train, validation_split=0.2, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 182/182 [==============================] - 19s 84ms/step - loss: 2.8294 - accuracy: 0.1173 - val_loss: 2.7420 - val_accuracy: 0.1587
# Epoch 2/10
# 182/182 [==============================] - 17s 94ms/step - loss: 2.5495 - accuracy: 0.2211 - val_loss: 2.6428 - val_accuracy: 0.1854
# Epoch 3/10
# 182/182 [==============================] - 17s 92ms/step - loss: 2.2912 - accuracy: 0.3213 - val_loss: 2.4398 - val_accuracy: 0.2596
# Epoch 4/10
# 182/182 [==============================] - 17s 91ms/step - loss: 2.1283 - accuracy: 0.3549 - val_loss: 2.4176 - val_accuracy: 0.2995
# Epoch 5/10
# 182/182 [==============================] - 17s 93ms/step - loss: 1.9725 - accuracy: 0.4169 - val_loss: 2.5053 - val_accuracy: 0.2905
# Epoch 6/10
# 182/182 [==============================] - 17s 92ms/step - loss: 1.8757 - accuracy: 0.4475 - val_loss: 2.3737 - val_accuracy: 0.3201
# Epoch 7/10
# 182/182 [==============================] - 17s 92ms/step - loss: 1.7866 - accuracy: 0.4733 - val_loss: 2.4285 - val_accuracy: 0.2988
# Epoch 8/10
# 182/182 [==============================] - 17s 92ms/step - loss: 1.7434 - accuracy: 0.4846 - val_loss: 2.5502 - val_accuracy: 0.2953
# Epoch 9/10
# 182/182 [==============================] - 17s 94ms/step - loss: 1.6494 - accuracy: 0.5265 - val_loss: 2.4102 - val_accuracy: 0.3077
# Epoch 10/10
# 182/182 [==============================] - 18s 98ms/step - loss: 1.5873 - accuracy: 0.5307 - val_loss: 2.6403 - val_accuracy: 0.3201

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(history.history["accuracy"],label="train")
plt.plot(history.history["val_accuracy"],label="test")
plt.legend()
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
model.evaluate(x_test, y_test)
# Out:
# 57/57 [==============================] - 0s 7ms/step - loss: 2.4959 - accuracy: 0.3385
# [2.4959166049957275, 0.3385041654109955]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

y_test_arg=np.argmax(y_test, axis=1)
Y_pred = np.argmax(model.predict(x_test),axis=1)
print('Confusion Matrix')
cm = confusion_matrix(y_test_arg, Y_pred)
# 시각화
plt.figure(figsize=(8, 6))  # 그래프 크기 조절 (너비 8, 높이 6)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

# 그래프 표시
plt.show()
# Out:
# 57/57 [==============================] - 0s 7ms/step
# Confusion Matrix

# %% [markdown]
# **시계열 데이터 먼저 만든 후 train,test,scaling,훈련 진행**

# %%
df = pd.read_csv("C:\\Users\\tbxjq\\Desktop\\가천대학교\\3학년 2학기\\딥러닝 응용\\Deep_learning_class\\data\\DSA_features.csv")
df=df.drop(['people'],axis=1)
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 9115  4.033226e-02     0.200829     -0.040701      0.297666     0.708480
# 9116  2.212497e-02     0.148745     -0.266377      0.224716     0.554670
# 9117  9.656444e-02     0.310748     -0.009505     -0.237786     0.088854
# 9118  2.448990e-02     0.156493      0.050624      0.533023     0.677800
# 9119  5.251176e-02     0.229154     -0.342228      0.491919     0.707920
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729     sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471     sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579     sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690     sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429     sitting
# ...           ...           ...          ...           ...         ...
# 9115    -0.117430  4.135451e-02     0.203358     -0.310022  basketBall
# 9116    -0.250950  3.355704e-02     0.183186     -0.736410  basketBall
# 9117    -0.477260  2.026107e-02     0.142341      0.668438  basketBall
# 9118     0.055941  1.356379e-02     0.116464     -1.482489  basketBall
# 9119     0.251280  9.358254e-03     0.096738     -0.223302  basketBall
#
# [9120 rows x 271 columns]

# %%
from sklearn.preprocessing import LabelEncoder


# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df['activity'] = label_encoder.fit_transform(df['activity'])
df

input = df.drop(['activity'],axis=1)
target = df['activity']

# %%
from collections import Counter

# timeseries
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # 시퀀스의 끝 인덱스 계산
        end_ix = i + n_steps
        if end_ix > len(sequences):  # 데이터 범위를 넘으면 종료
            break
        
        # 입력과 출력 데이터를 추출
        seq_x = sequences[i:end_ix, :-1]  # 입력 데이터
        seq_y_values = sequences[i:end_ix, -1]  # 해당 구간의 레이블들

        # 가장 빈번한 레이블을 선택
        most_common_label = Counter(seq_y_values).most_common(1)[0][0]

        X.append(seq_x)  # 입력 데이터 추가
        y.append(most_common_label)  # 가장 많이 나온 레이블 추가

    return np.array(X), np.array(y)  # Numpy 배열로 변환하여 반환

# %%
target = np.array(target)
train_set = np.c_[input,target]

# %%
n_steps = 20
input, target = split_sequences(train_set,n_steps)
input.shape, target.shape
# Out:
# ((9101, 20, 270), (9101,))

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(input,target,test_size=0.2,shuffle=True)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7280, 20, 270), (1821, 20, 270), (7280,), (1821,))

# %%
# 정수형 레이블을 벡터로 바꿔주기 원-핫 인코딩

from keras.utils import to_categorical
y_train= to_categorical(y_train)
y_test = to_categorical(y_test)

y_train.shape, y_test.shape
# Out:
# ((7280, 19), (1821, 19))

# %%
# Produce variables for CNN/LSTM/Transformer input/output shape
n_timesteps, n_features, n_outputs = x_train.shape[1], x_train.shape[2], y_train.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 20 270 19

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout,MultiHeadAttention,LayerNormalization
from tensorflow.keras.models import Model

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
# 하이퍼파라미터 설정
input_shape = (n_timesteps, n_features)  # 시퀀스 길이, 피처 수
n_classes = n_outputs  # 클래스 수
dropout = 0.5 # 드롭아웃 비율


model = build_model(
    input_shape=input_shape,
    head_size=64,
    num_heads=3,
    ff_dim=64,
    num_transformer_blocks=3,
    mlp_units=[128, 64],
    dropout=dropout,
    mlp_dropout=dropout
)
# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 요약
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 20, 270)]    0           []
#
#  multi_head_attention_1 (MultiH  (None, 20, 270)     208206      ['input_3[0][0]',
#  eadAttention)                                                    'input_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 20, 270)      0           ['multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 20, 270)     540         ['dropout_4[0][0]']
#  rmalization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'input_3[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 20, 64)       17344       ['tf.__operators__.add_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 20, 64)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 20, 270)      17550       ['dropout_5[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 20, 270)     540         ['conv1d_3[0][0]']
#  rmalization)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 20, 270)     208206      ['tf.__operators__.add_3[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 20, 270)      0           ['multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 20, 270)     540         ['dropout_6[0][0]']
#  rmalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 20, 64)       17344       ['tf.__operators__.add_4[0][0]']
#
#  dropout_7 (Dropout)            (None, 20, 64)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 20, 270)      17550       ['dropout_7[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 20, 270)     540         ['conv1d_5[0][0]']
#  rmalization)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  multi_head_attention_3 (MultiH  (None, 20, 270)     208206      ['tf.__operators__.add_5[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_5[0][0]']
#
#  dropout_8 (Dropout)            (None, 20, 270)      0           ['multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 20, 270)     540         ['dropout_8[0][0]']
#  rmalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 20, 64)       17344       ['tf.__operators__.add_6[0][0]']
#
#  dropout_9 (Dropout)            (None, 20, 64)       0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 20, 270)      17550       ['dropout_9[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 20, 270)     540         ['conv1d_7[0][0]']
#  rmalization)
#
#  tf.__operators__.add_7 (TFOpLa  (None, 20, 270)     0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 270)         0           ['tf.__operators__.add_7[0][0]']
#  obalAveragePooling1D)
#
#  dense_3 (Dense)                (None, 128)          34688       ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dropout_10 (Dropout)           (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 64)           8256        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 64)           0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 19)           1235        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 776,719
# Trainable params: 776,719
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 학습
history = model.fit(x_train, y_train, validation_split=0.2, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 182/182 [==============================] - 61s 281ms/step - loss: 3.0488 - accuracy: 0.3024 - val_loss: 1.1551 - val_accuracy: 0.6937
# Epoch 2/10
# 182/182 [==============================] - 51s 281ms/step - loss: 1.5022 - accuracy: 0.5258 - val_loss: 0.5449 - val_accuracy: 0.8729
# Epoch 3/10
# 182/182 [==============================] - 54s 297ms/step - loss: 1.0912 - accuracy: 0.6351 - val_loss: 0.3531 - val_accuracy: 0.8977
# Epoch 4/10
# 182/182 [==============================] - 51s 281ms/step - loss: 0.8347 - accuracy: 0.7172 - val_loss: 0.1792 - val_accuracy: 0.9327
# Epoch 5/10
# 182/182 [==============================] - 48s 265ms/step - loss: 0.6172 - accuracy: 0.7933 - val_loss: 0.1095 - val_accuracy: 0.9753
# Epoch 6/10
# 182/182 [==============================] - 49s 271ms/step - loss: 0.4633 - accuracy: 0.8384 - val_loss: 0.0895 - val_accuracy: 0.9801
# Epoch 7/10
# 182/182 [==============================] - 50s 277ms/step - loss: 0.4093 - accuracy: 0.8652 - val_loss: 0.0923 - val_accuracy: 0.9636
# Epoch 8/10
# 182/182 [==============================] - 49s 267ms/step - loss: 0.3025 - accuracy: 0.9037 - val_loss: 0.0932 - val_accuracy: 0.9670
# Epoch 9/10
# 182/182 [==============================] - 51s 282ms/step - loss: 0.2323 - accuracy: 0.9222 - val_loss: 0.1531 - val_accuracy: 0.9725
# Epoch 10/10
# 182/182 [==============================] - 49s 267ms/step - loss: 0.2211 - accuracy: 0.9311 - val_loss: 0.0337 - val_accuracy: 0.9876

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

y_test_arg=np.argmax(y_test, axis=1)
Y_pred = np.argmax(model.predict(x_test),axis=1)
print('Confusion Matrix')
cm = confusion_matrix(y_test_arg, Y_pred)
# 시각화
plt.figure(figsize=(8, 6))  # 그래프 크기 조절 (너비 8, 높이 6)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

# 그래프 표시
plt.show()
# Out:
# 57/57 [==============================] - 2s 20ms/step
# Confusion Matrix

# %%
model.evaluate(x_test,y_test)
# Out:
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0477 - accuracy: 0.9857
# [0.04773706570267677, 0.9857221245765686]
