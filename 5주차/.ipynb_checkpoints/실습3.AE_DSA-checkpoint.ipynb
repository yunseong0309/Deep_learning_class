# %% [markdown]
# # AE를 사용하여 DSA 실습

# %% [markdown]
# ## 1. **데이터 분석 및 전처리**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\tbxjq\\Desktop\\가천대학교\\3학년 2학기\\딥러닝 응용\\Deep_learning_class\\data\\DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9120 entries, 0 to 9119
# Columns: 272 entries, T_xacc_mean to people
# dtypes: float64(270), object(2)
# memory usage: 18.9+ MB

# %%
class_act = df['activity'].unique()
class_act
# Out:
# array(['sitting', 'standing', 'lyingBack', 'lyingRigh', 'ascendingStairs',
#        'decendingStairs', 'standingInElevatorStill', 'movingInElevator',
#        'walkingLot', 'walkingTreadmillFlat', 'walkingTreadmillIncline',
#        'runningTreadmill', 'stepper', 'crossTrainer', 'cyclingHorizontal',
#        'cyclingVertical', 'rowing', 'jumping', 'basketBall'], dtype=object)

# %%
# 결측치 확인
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **1. DSA데이터에서 sitting(normal) jumping(abnormal)만 남김**

# %%
df = df[(df['activity']=='jumping') | (df['activity']=='sitting')]
# people 열 삭제
df = df.drop(['people'],axis=1)
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# 1        0.552416     1.140865     1.21290     1.05810    0.000784  ...
# 2        0.100538     1.140962     1.21280     1.07960    0.000508  ...
# 3       -0.231914     1.165260     1.31700     1.07870    0.002173  ...
# 4        2.042285     1.187504     1.25740     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 8635  9.303061e-04     0.030501      0.334449      0.625187     0.691300
# 8636  9.968638e-04     0.031573      0.396417      0.624749     0.693560
# 8637  9.194098e-04     0.030322      0.524964      0.631822     0.690120
# 8638  5.788992e-04     0.024060      0.301200      0.624196     0.688560
# 8639  5.366838e-04     0.023166      0.395776      0.633913     0.692860
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729   sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471   sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579   sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690   sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429   sitting
# ...           ...           ...          ...           ...       ...
# 8635     0.571870  9.188517e-04     0.030313      0.274486   jumping
# 8636     0.570400  9.632708e-04     0.031037      0.433661   jumping
# 8637     0.581970  8.933477e-04     0.029889      0.335023   jumping
# 8638     0.573620  1.025797e-03     0.032028      0.272121   jumping
# 8639     0.586420  9.165240e-04     0.030274      0.342332   jumping
#
# [960 rows x 271 columns]

# %%
class_act = df['activity'].unique()
class_act
# Out:
# array(['sitting', 'jumping'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder=LabelEncoder()
df['activity']=label_encoder.fit_transform(df['activity'])
df

#sitting : 1, jumppint :0
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# 1        0.552416     1.140865     1.21290     1.05810    0.000784  ...
# 2        0.100538     1.140962     1.21280     1.07960    0.000508  ...
# 3       -0.231914     1.165260     1.31700     1.07870    0.002173  ...
# 4        2.042285     1.187504     1.25740     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 8635  9.303061e-04     0.030501      0.334449      0.625187     0.691300
# 8636  9.968638e-04     0.031573      0.396417      0.624749     0.693560
# 8637  9.194098e-04     0.030322      0.524964      0.631822     0.690120
# 8638  5.788992e-04     0.024060      0.301200      0.624196     0.688560
# 8639  5.366838e-04     0.023166      0.395776      0.633913     0.692860
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729         1
# 1       -0.059589  7.032302e-07     0.000839      0.347471         1
# 2       -0.059065  6.268222e-07     0.000792      0.045579         1
# 3       -0.058310  8.011245e-07     0.000895      0.240690         1
# 4       -0.057815  6.853423e-07     0.000828      0.258429         1
# ...           ...           ...          ...           ...       ...
# 8635     0.571870  9.188517e-04     0.030313      0.274486         0
# 8636     0.570400  9.632708e-04     0.031037      0.433661         0
# 8637     0.581970  8.933477e-04     0.029889      0.335023         0
# 8638     0.573620  1.025797e-03     0.032028      0.272121         0
# 8639     0.586420  9.165240e-04     0.030274      0.342332         0
#
# [960 rows x 271 columns]

# %% [markdown]
# 2. **두개 activity를 섞어서 training / test**
# 3. **training를 다시 training/valid**
# 4. **training/valid에서 jumping 데이터를 삭제 ( sitting를 정상데이터로 사용)**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# train, test, valid
x_train, x_test = train_test_split(df,test_size=0.2) # AE이기 때문에 target값은 필요 없음
x_train, x_valid = train_test_split(x_train, test_size=0.2)

# training/valid에서 jumping 데이터를 삭제 ( sitting 을 정상데이터로 사용)

x_train = x_train[x_train.activity == 0]
x_train=x_train.drop(['activity'],axis=1)

x_valid = x_valid[x_valid.activity ==0]
x_valid = x_valid.drop(['activity'],axis=1)

# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임

y_test = x_test['activity']

x_test = x_test.drop(['activity'],axis=1)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((306, 270), (83, 270), (192, 270))

# %%
# 표준화 하기. 표준화는 train에 fit한 결과를 바탕으로 나머지 valid,test에 적용해야한다.
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_valid=ss.transform(x_valid)
x_test=ss.transform(x_test)

# %%
LABELS = ["Normal","Abnormal"]
count_classes = pd.value_counts(df['activity'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("activity class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# C:\Users\tbxjq\AppData\Local\Temp\ipykernel_21236\2564224221.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['activity'], sort = True)

# %% [markdown]
# ## 2. AE 정의 및 학습

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

input_dim = x_train.shape[1]
#입력 차원의 1/10인 27을 넣을 수도 있다.
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 270)]             0
#
#  dense (Dense)               (None, 14)                3794
#
#  dense_1 (Dense)             (None, 7)                 105
#
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 270)               2160
#
# =================================================================
# Total params: 6,115
# Trainable params: 6,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train,x_train,epochs=50,batch_size=16,validation_data=(x_valid,x_valid),shuffle=True)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 2s 24ms/step - loss: 1.2418 - val_loss: 1.2021
# Epoch 2/50
# 20/20 [==============================] - 0s 5ms/step - loss: 1.2070 - val_loss: 1.1504
# Epoch 3/50
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1301 - val_loss: 1.0600
# Epoch 4/50
# 20/20 [==============================] - 0s 6ms/step - loss: 1.0238 - val_loss: 0.9675
# Epoch 5/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.9337 - val_loss: 0.9053
# Epoch 6/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.8791 - val_loss: 0.8680
# Epoch 7/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.8444 - val_loss: 0.8412
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8204 - val_loss: 0.8204
# Epoch 9/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8018 - val_loss: 0.8033
# Epoch 10/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7871 - val_loss: 0.7900
# Epoch 11/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7758 - val_loss: 0.7779
# Epoch 12/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7662 - val_loss: 0.7667
# Epoch 13/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7572 - val_loss: 0.7551
# Epoch 14/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7495 - val_loss: 0.7441
# Epoch 15/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7423 - val_loss: 0.7342
# Epoch 16/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7357 - val_loss: 0.7264
# Epoch 17/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7308 - val_loss: 0.7214
# Epoch 18/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7270 - val_loss: 0.7173
# Epoch 19/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7238 - val_loss: 0.7136
# Epoch 20/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7207 - val_loss: 0.7114
# Epoch 21/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7185 - val_loss: 0.7089
# Epoch 22/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7164 - val_loss: 0.7056
# Epoch 23/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7142 - val_loss: 0.7030
# Epoch 24/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7122 - val_loss: 0.7013
# Epoch 25/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7108 - val_loss: 0.6998
# Epoch 26/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7097 - val_loss: 0.6985
# Epoch 27/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7085 - val_loss: 0.6977
# Epoch 28/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7076 - val_loss: 0.6967
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7070 - val_loss: 0.6963
# Epoch 30/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7062 - val_loss: 0.6956
# Epoch 31/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7056 - val_loss: 0.6951
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7051 - val_loss: 0.6945
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7046 - val_loss: 0.6941
# Epoch 34/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7041 - val_loss: 0.6936
# Epoch 35/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7036 - val_loss: 0.6929
# Epoch 36/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7032 - val_loss: 0.6925
# Epoch 37/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7029 - val_loss: 0.6921
# Epoch 38/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7022 - val_loss: 0.6916
# Epoch 39/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7017 - val_loss: 0.6913
# Epoch 40/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7013 - val_loss: 0.6912
# Epoch 41/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7006 - val_loss: 0.6904
# Epoch 42/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7001 - val_loss: 0.6900
# Epoch 43/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6997 - val_loss: 0.6898
# Epoch 44/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6991 - val_loss: 0.6891
# Epoch 45/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6986 - val_loss: 0.6888
# Epoch 46/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6982 - val_loss: 0.6886
# Epoch 47/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6978 - val_loss: 0.6881
# Epoch 48/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6975 - val_loss: 0.6880
# Epoch 49/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6968 - val_loss: 0.6871
# Epoch 50/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6962 - val_loss: 0.6867

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df = error_df.reset_index(drop = True)

error_df.describe()
# Out:
# 6/6 [==============================] - 0s 2ms/step
#        reconstruction_error  true_class
# count            192.000000  192.000000
# mean               2.734563    0.526042
# std                1.963052    0.500627
# min                0.313214    0.000000
# 25%                0.610282    0.000000
# 50%                3.899751    1.000000
# 75%                4.505347    1.000000
# max                5.413931    1.000000

# %%
error_df.head()
# Out:
#    reconstruction_error  true_class
# 0              1.109815           0
# 1              4.235452           1
# 2              5.125454           1
# 3              4.053550           1
# 4              0.331203           0

# %%
error_df_normal = error_df[error_df['true_class'] == 0].reset_index(drop=True)

error_df_normal.describe()
# Out:
#        reconstruction_error  true_class
# count             91.000000        91.0
# mean               0.725958         0.0
# std                0.406178         0.0
# min                0.313214         0.0
# 25%                0.415111         0.0
# 50%                0.593044         0.0
# 75%                0.909873         0.0
# max                2.292361         0.0

# %%
error_df_abnormal = error_df[error_df['true_class'] == 1].reset_index(drop=True)

error_df_abnormal.describe()
# Out:
#        reconstruction_error  true_class
# count            101.000000       101.0
# mean               4.544296         1.0
# std                0.482251         0.0
# min                3.473330         1.0
# 25%                4.157925         1.0
# 50%                4.436815         1.0
# 75%                4.867521         1.0
# max                5.413931         1.0

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# 실제 클래스와 재구성 오류를 이용해 ROC 곡선 그리기
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

# ROC 곡선 시각화
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal Threshold: {optimal_threshold}")
# Out:
# Optimal Threshold: 3.4733298910232415

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음,

threshold = 3.4733298910232415

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",cmap="Blues");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        91
#            1       1.00      0.99      1.00       101
#
#     accuracy                           0.99       192
#    macro avg       0.99      1.00      0.99       192
# weighted avg       0.99      0.99      0.99       192
