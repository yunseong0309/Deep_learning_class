# %% [markdown]
# # Linear_AE ,DSA

# %% [markdown]
# * 선형 활성화 함수를 이용하여 오토인코더 모델 구현
# * 인코더와 디코더가 대칭인 것과 비대칭인 것 2가지 구현

# %% [markdown]
# ## 1. 데이터 분석 및 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\tbxjq\\Desktop\\가천대학교\\3학년 2학기\\딥러닝 응용\\Deep_learning_class\\data\\DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_std  \
# 0     1.083150      1.1832     0.99744    0.002208  ...     0.000792
# 1     1.140865      1.2129     1.05810    0.000784  ...     0.000860
# 2     1.140962      1.2128     1.07960    0.000508  ...     0.000762
# 3     1.165260      1.3170     1.07870    0.002173  ...     0.000735
# 4     1.187504      1.2574     1.09450    0.000662  ...     0.000824
#
#    LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min   LL_zmag_var  \
# 0      0.177075     -0.057119    -0.054963    -0.059241  6.778722e-07
# 1     -0.286918     -0.057268    -0.054945    -0.059589  7.032302e-07
# 2     -0.134430     -0.057068    -0.054711    -0.059065  6.268222e-07
# 3      0.021485     -0.056422    -0.053670    -0.058310  8.011245e-07
# 4     -0.148229     -0.055801    -0.053313    -0.057815  6.853423e-07
#
#    LL_zmag_std  LL_zmag_skew  activity  people
# 0     0.000823      0.036729   sitting      p1
# 1     0.000839      0.347471   sitting      p1
# 2     0.000792      0.045579   sitting      p1
# 3     0.000895      0.240690   sitting      p1
# 4     0.000828      0.258429   sitting      p1
#
# [5 rows x 272 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
print(df['activity'].unique())
# Out:
# ['sitting' 'standing' 'lyingBack' 'lyingRigh' 'ascendingStairs'
#  'decendingStairs' 'standingInElevatorStill' 'movingInElevator'
#  'walkingLot' 'walkingTreadmillFlat' 'walkingTreadmillIncline'
#  'runningTreadmill' 'stepper' 'crossTrainer' 'cyclingHorizontal'
#  'cyclingVertical' 'rowing' 'jumping' 'basketBall']

# %%
# activity 열에서 'lyingBack', 'lyingRigh', 'sitting' 만 추출하기
df = df[df['activity'].isin(['lyingBack', 'lyingRigh', 'sitting'])]
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987    -0.382210    -0.446050
# 1916     0.008588      0.147180     -0.411248    -0.365810    -0.436760
# 1917     0.005814      0.032341     -0.409787    -0.379260    -0.434310
# 1918     0.009510      0.409508     -0.409101    -0.360740    -0.440870
# 1919     0.009874      0.413339     -0.410440    -0.385880    -0.438410
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew   activity  people
# 0     6.778722e-07     0.000823      0.036729    sitting      p1
# 1     7.032302e-07     0.000839      0.347471    sitting      p1
# 2     6.268222e-07     0.000792      0.045579    sitting      p1
# 3     8.011245e-07     0.000895      0.240690    sitting      p1
# 4     6.853423e-07     0.000828      0.258429    sitting      p1
# ...            ...          ...           ...        ...     ...
# 1915  9.935077e-05     0.009967     -0.597598  lyingRigh      p8
# 1916  8.659481e-05     0.009306      1.021454  lyingRigh      p8
# 1917  7.258946e-05     0.008520      0.431012  lyingRigh      p8
# 1918  1.127801e-04     0.010620      1.368666  lyingRigh      p8
# 1919  7.216993e-05     0.008495      0.054973  lyingRigh      p8
#
# [1440 rows x 272 columns]

# %%
# 제대로 원하는 값들이 추출되었는지 확인하는 과정
df['activity'].unique(), df.shape, df['activity'].value_counts()
# Out:
# (array(['sitting', 'lyingBack', 'lyingRigh'], dtype=object),
#  (1440, 272),
#  activity
#  sitting      480
#  lyingBack    480
#  lyingRigh    480
#  Name: count, dtype: int64)

# %%
# 'activity' 열 전처리: lyingBack, lyingRigh -> 정상 (0), sitting -> 비정상 (1)
df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
df
# Out:
# C:\Users\tbxjq\AppData\Local\Temp\ipykernel_4064\1868954632.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
# C:\Users\tbxjq\AppData\Local\Temp\ipykernel_4064\1868954632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987    -0.382210    -0.446050
# 1916     0.008588      0.147180     -0.411248    -0.365810    -0.436760
# 1917     0.005814      0.032341     -0.409787    -0.379260    -0.434310
# 1918     0.009510      0.409508     -0.409101    -0.360740    -0.440870
# 1919     0.009874      0.413339     -0.410440    -0.385880    -0.438410
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity  people
# 0     6.778722e-07     0.000823      0.036729         1      p1
# 1     7.032302e-07     0.000839      0.347471         1      p1
# 2     6.268222e-07     0.000792      0.045579         1      p1
# 3     8.011245e-07     0.000895      0.240690         1      p1
# 4     6.853423e-07     0.000828      0.258429         1      p1
# ...            ...          ...           ...       ...     ...
# 1915  9.935077e-05     0.009967     -0.597598         0      p8
# 1916  8.659481e-05     0.009306      1.021454         0      p8
# 1917  7.258946e-05     0.008520      0.431012         0      p8
# 1918  1.127801e-04     0.010620      1.368666         0      p8
# 1919  7.216993e-05     0.008495      0.054973         0      p8
#
# [1440 rows x 272 columns]

# %%
# 비율 확인
LABELS = ["Normal","Abnormal"]
count_classes = pd.value_counts(df['activity'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("activity class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# C:\Users\tbxjq\AppData\Local\Temp\ipykernel_4064\3755690299.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['activity'], sort = True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_train, x_test = train_test_split(df, test_size=0.2,shuffle=True, random_state=42)
x_train, x_valid = train_test_split(x_train, test_size=0.2,shuffle=True, random_state=42)

# 정상 데이터(0)만 사용하여 학습에 활용 (lyingBack, lyingRight)
# values를 통해 넘파이 배열로 바꿔주기
x_train = x_train[x_train.activity == 0]
x_train = x_train.drop(['activity', 'people'], axis=1).values

x_valid = x_valid[x_valid.activity == 0]
x_valid = x_valid.drop(['activity', 'people'], axis=1).values

# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임
y_test = x_test['activity']  # 테스트 데이터에서 활동 라벨만 남기기
x_test = x_test.drop(['activity', 'people'], axis=1).values

x_train.shape, x_valid.shape, x_test.shape, y_test.shape
# Out:
# ((607, 270), (156, 270), (288, 270), (288,))

# %%
# StandardScaler로 데이터 정규화
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_valid = scaler.transform(x_valid)
x_test = scaler.transform(x_test)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((607, 270), (156, 270), (288, 270))

# %% [markdown]
# ## 2. 선형 오토인코더 모델 구현

# %% [markdown]
# linear_AE는 비선형 활성화 함수가 아닌 linear적용

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# 선형 오토인코더 모델
input_dim = x_train.shape[1]
#입력 차원의 1/10인 27을 넣을 수도 있다.
encoding_dim = 27  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)


def linear_autoencoder(input_dim, encoding_dim):

    input_layer = Input(shape=(input_dim,))
    encoded = Dense(encoding_dim, activation='linear')(input_layer)
    encoded = Dense(int(encoding_dim/2), activation='linear')(encoded)
    decoded = Dense(int(encoding_dim/2), activation='linear')(encoded)
    decoded = Dense(input_dim, activation='linear')(decoded)

    # Autoencoder 모델
    autoencoder = Model(inputs=input_layer, outputs=decoded)
    return autoencoder

# 모델 빌드
autoencoder = linear_autoencoder(input_dim, encoding_dim)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 270)]             0
#
#  dense (Dense)               (None, 27)                7317
#
#  dense_1 (Dense)             (None, 13)                364
#
#  dense_2 (Dense)             (None, 13)                182
#
#  dense_3 (Dense)             (None, 270)               3780
#
# =================================================================
# Total params: 11,643
# Trainable params: 11,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train,x_train,epochs=50,batch_size=32,validation_data=(x_valid,x_valid),shuffle=True)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 2s 22ms/step - loss: 1.1427 - val_loss: 0.7035
# Epoch 2/50
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0136 - val_loss: 0.6757
# Epoch 3/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9491 - val_loss: 0.6252
# Epoch 4/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8839 - val_loss: 0.5724
# Epoch 5/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8110 - val_loss: 0.5179
# Epoch 6/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7342 - val_loss: 0.4829
# Epoch 7/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6743 - val_loss: 0.4526
# Epoch 8/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6301 - val_loss: 0.4334
# Epoch 9/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5909 - val_loss: 0.4142
# Epoch 10/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5556 - val_loss: 0.3979
# Epoch 11/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5262 - val_loss: 0.3875
# Epoch 12/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4995 - val_loss: 0.3722
# Epoch 13/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4792 - val_loss: 0.3716
# Epoch 14/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4833 - val_loss: 0.3730
# Epoch 15/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4815 - val_loss: 0.3511
# Epoch 16/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4852 - val_loss: 0.3417
# Epoch 17/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4350 - val_loss: 0.3368
# Epoch 18/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4284 - val_loss: 0.3300
# Epoch 19/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4162 - val_loss: 0.3230
# Epoch 20/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4083 - val_loss: 0.3170
# Epoch 21/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4001 - val_loss: 0.3124
# Epoch 22/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3950 - val_loss: 0.3080
# Epoch 23/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3881 - val_loss: 0.3042
# Epoch 24/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3828 - val_loss: 0.2987
# Epoch 25/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3788 - val_loss: 0.2958
# Epoch 26/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3745 - val_loss: 0.2918
# Epoch 27/50
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3694 - val_loss: 0.2885
# Epoch 28/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3657 - val_loss: 0.2855
# Epoch 29/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3654 - val_loss: 0.2834
# Epoch 30/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3593 - val_loss: 0.2800
# Epoch 31/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3538 - val_loss: 0.2783
# Epoch 32/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3503 - val_loss: 0.2756
# Epoch 33/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3469 - val_loss: 0.2739
# Epoch 34/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3428 - val_loss: 0.2715
# Epoch 35/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3389 - val_loss: 0.2698
# Epoch 36/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3368 - val_loss: 0.2688
# Epoch 37/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3373 - val_loss: 0.2666
# Epoch 38/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3360 - val_loss: 0.2662
# Epoch 39/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3417 - val_loss: 0.2664
# Epoch 40/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3530 - val_loss: 0.2808
# Epoch 41/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3546 - val_loss: 0.2654
# Epoch 42/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3318 - val_loss: 0.2742
# Epoch 43/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3342 - val_loss: 0.2641
# Epoch 44/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3203 - val_loss: 0.2601
# Epoch 45/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3157 - val_loss: 0.2596
# Epoch 46/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3096 - val_loss: 0.2567
# Epoch 47/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3081 - val_loss: 0.2575
# Epoch 48/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3041 - val_loss: 0.2561
# Epoch 49/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3045 - val_loss: 0.2557
# Epoch 50/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2979 - val_loss: 0.2551

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨
# 오토인코더를 사용한 이상 탐지에서, 재구성 오류(Reconstruction Error)는 입력 데이터가
# 얼마나 잘 복원되었는지 측정하는 값
# 이를 통해 정상 데이터와 비정상 데이터를 구분할 수 있다.
# 재구성 오류 값은 test-predic 의 제곱의 평균인 MSE 로 나타내어 표기한다.

predictions = autoencoder.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df = error_df.reset_index(drop = True)

error_df.describe()
# Out:
# 9/9 [==============================] - 0s 2ms/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               3.302381    0.315972
# std               39.549519    0.465711
# min                0.058352    0.000000
# 25%                0.111724    0.000000
# 50%                0.244867    0.000000
# 75%                0.610454    1.000000
# max              662.769272    1.000000

# %%
error_df.head()
# Out:
#    reconstruction_error  true_class
# 0              0.767308           1
# 1              0.202101           0
# 2              0.366935           0
# 3              1.149859           1
# 4              0.171864           0

# %%
error_df_normal = error_df[error_df['true_class'] == 0].reset_index(drop=True)

error_df_normal.describe()
# Out:
#        reconstruction_error  true_class
# count            197.000000       197.0
# mean               0.272038         0.0
# std                0.552908         0.0
# min                0.058352         0.0
# 25%                0.100313         0.0
# 50%                0.132960         0.0
# 75%                0.246248         0.0
# max                4.645939         0.0

# %%
error_df_abnormal = error_df[error_df['true_class'] == 1].reset_index(drop=True)

error_df_abnormal.describe()
# Out:
#        reconstruction_error  true_class
# count             91.000000        91.0
# mean               9.862576         1.0
# std               70.168840         0.0
# min                0.299183         1.0
# 25%                0.590517         1.0
# 50%                0.721911         1.0
# 75%                0.976345         1.0
# max              662.769272         1.0

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음,

threshold =0.3

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",cmap="Blues");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92       197
#            1       0.75      0.99      0.85        91
#
#     accuracy                           0.89       288
#    macro avg       0.87      0.92      0.88       288
# weighted avg       0.92      0.89      0.90       288

# %% [markdown]
# **비대칭 선형 오토인코더**

# %%
# 비선형 오토인코더 모델
input_dim = x_train.shape[1]
#입력 차원의 1/10인 27을 넣을 수도 있다.
encoding_dim = 27  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)


def linear_asymmetric_autoencoder(input_dim, encoding_dim):

    input_layer = Input(shape=(input_dim,))
    # 첫 번째 인코더 층
    encoded = Dense(int(encoding_dim*2), activation='linear')(input_layer)
    # 두 번째 인코더 층(최종 압축)
    encoded = Dense(int(encoding_dim/2), activation='linear')(encoded)

    # 첫 번째 디코더 층
    decoded = Dense(int(encoding_dim), activation='linear')(encoded)
    # 두 번째 디코더 층
    decoded = Dense(int(encoding_dim*2), activation='linear')(decoded)
    # 세번째 디코더 층(최종 복원 층)
    decoded = Dense(input_dim, activation='linear')(decoded)

    # Autoencoder 모델
    autoencoder = Model(inputs=input_layer, outputs=decoded)
    return autoencoder

# 모델 빌드
asy_autoencoder = linear_asymmetric_autoencoder(input_dim, encoding_dim)

asy_autoencoder.compile(optimizer='adam', loss='mse')
asy_autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 270)]             0
#
#  dense_4 (Dense)             (None, 54)                14634
#
#  dense_5 (Dense)             (None, 13)                715
#
#  dense_6 (Dense)             (None, 27)                378
#
#  dense_7 (Dense)             (None, 54)                1512
#
#  dense_8 (Dense)             (None, 270)               14850
#
# =================================================================
# Total params: 32,089
# Trainable params: 32,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = asy_autoencoder.fit(x_train,x_train,epochs=50,batch_size=32,validation_data=(x_valid,x_valid),shuffle=True)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 2s 27ms/step - loss: 1.1628 - val_loss: 0.6998
# Epoch 2/50
# 19/19 [==============================] - 0s 14ms/step - loss: 0.9484 - val_loss: 0.5677
# Epoch 3/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7977 - val_loss: 0.4784
# Epoch 4/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6721 - val_loss: 0.4339
# Epoch 5/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5821 - val_loss: 0.3960
# Epoch 6/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5091 - val_loss: 0.3659
# Epoch 7/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4599 - val_loss: 0.3430
# Epoch 8/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4287 - val_loss: 0.3255
# Epoch 9/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4317 - val_loss: 0.3121
# Epoch 10/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4124 - val_loss: 0.2988
# Epoch 11/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3921 - val_loss: 0.2968
# Epoch 12/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3924 - val_loss: 0.3016
# Epoch 13/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3913 - val_loss: 0.2925
# Epoch 14/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3783 - val_loss: 0.2782
# Epoch 15/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3506 - val_loss: 0.2736
# Epoch 16/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3814 - val_loss: 0.2771
# Epoch 17/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3773 - val_loss: 0.2734
# Epoch 18/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3338 - val_loss: 0.2631
# Epoch 19/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3241 - val_loss: 0.2605
# Epoch 20/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3464 - val_loss: 0.2647
# Epoch 21/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3073 - val_loss: 0.2646
# Epoch 22/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3001 - val_loss: 0.2534
# Epoch 23/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2971 - val_loss: 0.2553
# Epoch 24/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2875 - val_loss: 0.2544
# Epoch 25/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2933 - val_loss: 0.2532
# Epoch 26/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2838 - val_loss: 0.2491
# Epoch 27/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2830 - val_loss: 0.2503
# Epoch 28/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2913 - val_loss: 0.2469
# Epoch 29/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3134 - val_loss: 0.2474
# Epoch 30/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2633 - val_loss: 0.2439
# Epoch 31/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2565 - val_loss: 0.2408
# Epoch 32/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2530 - val_loss: 0.2413
# Epoch 33/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2527 - val_loss: 0.2396
# Epoch 34/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2530 - val_loss: 0.2414
# Epoch 35/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2490 - val_loss: 0.2465
# Epoch 36/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2537 - val_loss: 0.2497
# Epoch 37/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2585 - val_loss: 0.2409
# Epoch 38/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2656 - val_loss: 0.2429
# Epoch 39/50
# 19/19 [==============================] - 0s 12ms/step - loss: 0.2581 - val_loss: 0.2416
# Epoch 40/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2813 - val_loss: 0.2401
# Epoch 41/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2473 - val_loss: 0.2417
# Epoch 42/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2428 - val_loss: 0.2489
# Epoch 43/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2477 - val_loss: 0.2497
# Epoch 44/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2452
# Epoch 45/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2578 - val_loss: 0.2374
# Epoch 46/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2650 - val_loss: 0.2440
# Epoch 47/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2447 - val_loss: 0.2374
# Epoch 48/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2334 - val_loss: 0.2349
# Epoch 49/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2304 - val_loss: 0.2352
# Epoch 50/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2282 - val_loss: 0.2343

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨
# 오토인코더를 사용한 이상 탐지에서, 재구성 오류(Reconstruction Error)는 입력 데이터가
# 얼마나 잘 복원되었는지 측정하는 값
# 이를 통해 정상 데이터와 비정상 데이터를 구분할 수 있다.
# 재구성 오류 값은 test-predic 의 제곱의 평균인 MSE 로 나타내어 표기한다.

predictions = asy_autoencoder.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df = error_df.reset_index(drop = True)

error_df.describe()
# Out:
# 9/9 [==============================] - 0s 2ms/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               3.100174    0.315972
# std               36.701795    0.465711
# min                0.047419    0.000000
# 25%                0.102882    0.000000
# 50%                0.204309    0.000000
# 75%                0.595479    1.000000
# max              613.430534    1.000000

# %%
error_df_normal = error_df[error_df['true_class'] == 0].reset_index(drop=True)

error_df_normal.describe()
# Out:
#        reconstruction_error  true_class
# count            197.000000       197.0
# mean               0.247331         0.0
# std                0.507610         0.0
# min                0.047419         0.0
# 25%                0.092363         0.0
# 50%                0.120250         0.0
# 75%                0.207510         0.0
# max                4.371487         0.0

# %%
error_df_abnormal = error_df[error_df['true_class'] == 1].reset_index(drop=True)

error_df_abnormal.describe()
# Out:
#        reconstruction_error  true_class
# count             91.000000        91.0
# mean               9.276109         1.0
# std               65.104230         0.0
# min                0.297450         1.0
# 25%                0.561922         1.0
# 50%                0.696548         1.0
# 75%                0.878287         1.0
# max              613.430534         1.0

# %%
threshold = 0.2

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",cmap="Blues");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84       197
#            1       0.63      1.00      0.77        91
#
#     accuracy                           0.81       288
#    macro avg       0.81      0.86      0.81       288
# weighted avg       0.88      0.81      0.82       288
